# %%
#read data
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori,association_rules
data_1 = pd.read_csv("breast_cancer_bd.csv",dtype = str)

# %%
data_ori = data_1.iloc[:,1:10]
c1 = data_ori
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
#区分不同的属性        
c1.iloc[:,0] = pd.Series(c1.iloc[:,0])+"a"
c1.iloc[:,1] = pd.Series(c1.iloc[:,1])+"b"
c1.iloc[:,2] = pd.Series(c1.iloc[:,2])+"c"
c1.iloc[:,3] = pd.Series(c1.iloc[:,3])+"d"
c1.iloc[:,4] = pd.Series(c1.iloc[:,4])+"e"
c1.iloc[:,5] = pd.Series(c1.iloc[:,5])+"f"
c1.iloc[:,6] = pd.Series(c1.iloc[:,6])+"g"
c1.iloc[:,7] = pd.Series(c1.iloc[:,7])+"h"
c1.iloc[:,8] = pd.Series(c1.iloc[:,8])+"i"
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1843: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item_labels[indexer[info_axis]]] = value

# %%
#在进行处理时需要二维列表
c=c1.values
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
te = TransactionEncoder()
te_c = te.fit_transform(c)
df = pd.DataFrame(te_c,columns = te.columns_)
item = apriori(df,min_support = 0.4,use_colnames = True)
rules = association_rules(item,min_threshold =0.8)
rules
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#       antecedents consequents  antecedent support  consequent support  \
# 0            (1b)        (1c)            0.549356            0.505007
# 1            (1c)        (1b)            0.505007            0.549356
# 2            (1d)        (1b)            0.582260            0.549356
# 3            (1b)        (1d)            0.549356            0.582260
# 4            (1f)        (1b)            0.575107            0.549356
# ..            ...         ...                 ...                 ...
# 219  (1f, 2e, 1h)        (1i)            0.420601            0.828326
# ...

# %%
for i,j in rules.iterrows():
    X = j['antecedents']
    Y = j['consequents']
    x = ','.join([item for item in X])
    y = ','.join([item for item in Y])
    print(x+'->'+ y)
# Out:
# 1b->1c
# 1c->1b
# 1d->1b
# 1b->1d
# 1f->1b
# 1b->1f
# 1b->1h
# 1h->1b
# 1b->1i
# 2e->1b
# 1b->2e
# 1c->1d
# 1c->1f
# 1c->1h
# 1c->1i
# 1c->2e
# 1f->1d
# 1d->1f
# 1d->1h
# 1d->1i
# 2e->1d
# 1f->1h
# 1h->1f
# 1f->1i
# 2e->1f
# 1h->1i
# 2e->1h
# 2e->1i
# 1d,1b->1c
# 1d,1c->1b
# 1b,1c->1d
# 1c->1d,1b
# 1f,1b->1c
# 1f,1c->1b
# 1b,1c->1f
# 1c->1f,1b
# 1b,1h->1c
# 1b,1c->1h
# 1h,1c->1b
# 1b->1h,1c
# 1c->1b,1h
# 1i,1b->1c
# 1i,1c->1b
# 1b,1c->1i
# 1b->1i,1c
# 1c->1i,1b
# 1f,1d->1b
# 1f,1b->1d
# 1d,1b->1f
# 1d,1b->1h
# 1d,1h->1b
# 1b,1h->1d
# 1b->1d,1h
# 1i,1b->1d
# 1i,1d->1b
# 1d,1b->1i
# 1b->1i,1d
# 1d->1i,1b
# 2e,1d->1b
# 2e,1b->1d
# 1d,1b->2e
# 1f,1b->1h
# 1f,1h->1b
# 1b,1h->1f
# 1b->1f,1h
# 1f,1i->1b
# 1f,1b->1i
# 1i,1b->1f
# 1f->1i,1b
# 1b->1f,1i
# 1f,2e->1b
# 1f,1b->2e
# 2e,1b->1f
# 1i,1b->1h
# 1i,1h->1b
# 1b,1h->1i
# 1b->1i,1h
# 2e,1b->1h
# 2e,1h->1b
# 1b,1h->2e
# 2e,1i->1b
# 2e,1b->1i
# 1i,1b->2e
# 2e->1i,1b
# 1b->2e,1i
# 1d,1h->1c
# 1d,1c->1h
# 1h,1c->1d
# 1c->1d,1h
# 1i,1c->1d
# ...
